# %% [markdown]
# # EVE 310 - Lab 03: Working with dataframes — activity
#
# **Module 1 | 09/10/2026**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThyanRevolter/eve310-fall-2026/blob/main/labs/lab03-pandas-dataframes/notebooks/lab03-activity.ipynb)
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. Inspect a dataframe with `head`, `size`, `shape`, `describe`, and `info`
# 2. Rename, drop, and add columns
# 3. Extract a column with `loc` or `iloc`
#
# ## Before you start
#
# 1. Click **Copy to Drive** at the top of this window and work in the copy that opens. Colab throws away anything you did not copy when the runtime ends.
# 2. Run the setup cell below before anything else. It creates `DATA_DIR` and `FIGURES_DIR` and downloads this lab's data file.
# 3. Work down the notebook in order. Replace every `--` with your code and keep the variable names exactly as given.
# 4. When you are done: **Runtime > Restart session and run all**, then **File > Download > Download .ipynb**, and upload that file to Gradescope. The Gradescope autograder gives you feedback on each variable, but **this submission is not graded** and does not count toward your final grade. The Lab 3 quiz on Canvas is what counts, and it asks about the values you compute here, so finish the activity before you take it.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd

# EVE 310 setup - run this cell first, every time you open this notebook.
# It downloads this lab's data files into a "data" folder in your Colab session.
import pathlib
import urllib.request

LAB = "lab03-pandas-dataframes"
DATA_FILES = ["JES_Water_Lab3.csv"]

DATA_DIR = pathlib.Path("data")
FIGURES_DIR = pathlib.Path("figures")
DATA_DIR.mkdir(exist_ok=True)
FIGURES_DIR.mkdir(exist_ok=True)

BASE_URL = f"https://raw.githubusercontent.com/ThyanRevolter/eve310-fall-2026/main/labs/{LAB}/data"
for name in DATA_FILES:
    if not (DATA_DIR / name).exists():
        urllib.request.urlretrieve(f"{BASE_URL}/{name}", DATA_DIR / name)

print(f"Ready. {len(DATA_FILES)} data file(s) in {DATA_DIR.resolve()}")

# %% [markdown]
# **Load the data**
#
# Load `DATA_DIR / 'JES_Water_Lab3.csv'` into `water_df`. This is a shorter extract of the Jester Hall water dataset from the tutorial: the same columns, fewer rows.

# %%
water_df = ---

# %% [markdown]
# ## Your turn
#
# **Part A — First rows**
#
# Store the first 7 rows of `water_df` in `first_rows`, then display it. In Colab, a variable on the last line of a cell displays on its own.

# %%
first_rows = --
first_rows

# %% [markdown]
# **Part B — Size**
#
# Store the total number of values in the dataframe in `df_size`.
#
# *Hint: `size` and `shape` are attributes, not methods, so there are no parentheses after them.*

# %%
df_size = --
print('The size of the dataframe is', df_size)

# %% [markdown]
# **Part C — Shape**
#
# Store the number of rows and columns in `df_shape`, then print each one.

# %%
df_shape = --
print('The number of rows is', df_shape[--])
print('The number of columns is', df_shape[--])

# %% [markdown]
# **Part D — Summary statistics**
#
# Compute the summary statistics for each column with `describe` and store the result in `stats`, then display it. Then assign the minimum value of the `wF` column to `min_wF`.

# %%
stats = --
min_wF = --

# %% [markdown]
# **Part E — Metadata**
#
# Display the metadata of the dataframe with `info`. This method prints its output and does not return anything. Just call print() on the `info()` method. Then find the number of missing values in the `prevWeek` column and assign it to `prevWeek_missing` variable.

# %%
# call info() on water_df
print(---)

# %%
prevWeek_missing = ---

# %% [markdown]
# **Part F — Rename a column**
#
# Store your first name as a string in `my_name`, then rename the column currently labeled `MonMed` to `my_name`. Assign the result back to `water_df`.
#
# *Hint: `rename` takes a dictionary, `columns={'old name': 'new name'}`. It returns a new dataframe instead of changing `water_df` in place, which is why you assign the result back.*

# %%
my_name = --
water_df = water_df.rename(columns={--: --})
water_df.head(3)

# %% [markdown]
# **Part G — Remove a column**
#
# Remove the column labeled `avgTemp` and assign the result back to `water_df`.
#
# *Hint: `axis=1` tells `drop` you mean a column, not a row.*

# %%
water_df = --
water_df.head(3)

# %% [markdown]
# **Part H — Extract a column**
#
# Use `loc` or `iloc` to extract the column `wF` into a variable called `water_col`.
#
# *Hint: remember which symbol selects all of the rows or columns of an array in Lab 2. The same convention applies to `loc` and `iloc`. With `loc` you use the column name; with `iloc` you use its position, counting from 0 and counting after `avgTemp` was removed in Part G.*

# %%
water_col = --
water_col

# %% [markdown]
# **Part I — Add a column**
#
# Create a new column on the dataframe called `'Water 2x'` and assign it two times the values in the `wF` column.
#
# *Hint: arithmetic on a whole column works one row at a time, so `water_df['wF'] * 2` is already a full column of values.*

# %%
water_df['Water 2x'] = --

# %% [markdown]
# **Part J — Check your work**
#
# Store the first 5 rows of the dataframe in `new_rows` and display it, so you can see the renamed column, the missing `avgTemp` column, and the new `Water 2x` column.

# %%
new_rows = --
new_rows

# %% [markdown]
# **Part K — Quiz scratch space**
#
# The Canvas quiz will ask questions about `water_df`, `water_col`, and the outputs above. Use the cell below during the quiz.
#
# **DO NOT OVERWRITE ANY VARIABLES ABOVE THIS CELL. CREATE NEW VARIABLES AS NEEDED.**

# %%
# Use this cell for quiz calculations

# %% [markdown]
# ## Wrap-up
#
# **Runtime > Restart session and run all**, confirm every cell runs top to bottom, then **File > Download > Download .ipynb** and upload it to Gradescope for feedback. The submission is not graded. Keep this notebook open for the Canvas quiz.
