# %% [markdown]
# # EVE 310 - Lab 01: Python basics — activity
#
# **Module 1 | 08/27/2026**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThyanRevolter/eve310-fall-2026/blob/main/labs/lab01-python-intro/notebooks/lab01-activity.ipynb)
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. Convert units and apply a recovery rate
# 2. Compute energy use and operating cost per cubic meter
# 3. Compare cost metrics at different recovery rates
#
# ## Before you start
#
# - Run `uv sync` in the repository root, then launch this notebook with `uv run jupyter lab` (see `docs/setup.md`).
# - Work through the cells in order. Cells marked **Your turn** are for you to complete.

# %% [markdown]
# ## Reverse-osmosis plant
#
# An RO plant is being designed to treat brackish groundwater for a small community. Submit the completed notebook. Write formulas in comments above your calculations.
#
# Design values:
#
# - Feed flow: 500,000 liters/day
# - Recovery rate: 75%
# - Feedwater TDS: 2,000 mg/L
# - Permeate TDS target: 250 mg/L
# - Electricity cost: \$0.09 per kWh
# - Specific energy consumption: 1.2 kWh per m³ of **treated** water
# - Membrane replacement: \$12,000 every 3 years
# - Daily operating cost (chemicals, labor, etc.): \$450
# - Capital cost: \$500,000

# %% [markdown]
# ## Your turn
#
# **Exercise 1.** Convert the daily feed volume to m³/day. Save it as `mld`.

# %%
# 1 m3 = 1000 liters
mld = None  # your code here
print(f'This plant treats {mld} m3 of brackish water per day')

# %% [markdown]
# **Exercise 2.** Using the recovery rate, calculate treated water and brine each day (m³/day). Save `treated_mld` and `brine_mld`.

# %%
treated_mld = None
brine_mld = None
print(f'Treated {treated_mld} m3/day, brine {brine_mld} m3/day')

# %% [markdown]
# **Exercise 3.** Energy consumed per day (kWh/day) and energy cost per day. Save `energy_per_day` and `energy_cost_per_day`.

# %%
energy_per_day = None
energy_cost_per_day = None
print(f'{energy_per_day} kWh/day, ${energy_cost_per_day}/day')

# %% [markdown]
# **Exercise 4.** Using a daily operating cost of **\$500/day** (as stated in the original activity), compute operating, energy, and total cost per m³ of treated water.

# %%
operating_cost_per_m3 = None
energy_cost_per_m3 = None
total_cost_per_m3 = None
print(operating_cost_per_m3, energy_cost_per_m3, total_cost_per_m3)

# %% [markdown]
# **Exercise 5.** Fraction of total cost from operating cost and from energy cost.

# %%
fraction_by_operating_cost = None
fraction_by_energy_cost = None
print(fraction_by_operating_cost, fraction_by_energy_cost)

# %% [markdown]
# **Exercise 6.** How do operating, energy, and total cost per m³ change if recovery is 65%, 50%, or 80%? Keep energy use tied to treated volume.

# %%
op_cost_65 = energy_cost_65 = total_cost_65 = None
op_cost_50 = energy_cost_50 = total_cost_50 = None
op_cost_80 = energy_cost_80 = total_cost_80 = None
print('65%', op_cost_65, energy_cost_65, total_cost_65)
print('50%', op_cost_50, energy_cost_50, total_cost_50)
print('80%', op_cost_80, energy_cost_80, total_cost_80)

# %% [markdown]
# ## Wrap-up
#
# Submit the completed notebook as described in `../README.md`.
