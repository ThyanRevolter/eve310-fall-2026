# %% [markdown]
# # EVE 310 - Lab 01: Python basics
#
# **Module 1 | 08/27/2026**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThyanRevolter/eve310-fall-2026/blob/main/labs/lab01-python-basics/notebooks/lab01-tutorial.ipynb)
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. Use variables, arithmetic, and `print` in a Jupyter notebook
# 2. Import `numpy` and call common math functions
# 3. Work through a short reverse-osmosis cost calculation
#
# ## Before you start
#
# - **On your laptop:** run `uv sync` in the repository root, then launch this notebook with `uv run jupyter lab` (see `docs/setup.md`).
# - **In Google Colab:** click *Copy to Drive* first, or your work is lost when the tab closes.
# - Either way, run the setup cell below before anything else. You do not need to understand it yet — it prepares the course data and plotting defaults.
# - Work through the cells in order. Cells marked **Your turn** are for you to complete.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np

# Course setup: run this cell first. It works on your laptop and in Google Colab.
LAB = "lab01-python-intro"
try:
    from eve310 import setup_notebook
except ModuleNotFoundError:
    # Colab starts from a blank machine, so download the course files first.
    # !test -d /content/eve310 || git clone -q --depth 1 https://github.com/ThyanRevolter/eve310-fall-2026.git /content/eve310
    import sys
    sys.path.insert(0, "/content/eve310/src")
    from eve310 import setup_notebook

DATA_DIR, FIGURES_DIR = setup_notebook(LAB)

# %% [markdown]
# ## 1. Types, comments, and variables
#
# Integer values have type `int`, decimals are `float`, text is `str`. Use `#` for a single-line comment.

# %%
print(1 / 2)              # division always returns a float
print('Hello World')

x = 1 / 2                 # assignment does not print
print(x)
print(type(x))

x = 5 * 5                 # overwritten with an int
print(x, type(x))

x = 'I love coding'       # now a string
print(x, type(x))

# %% [markdown]
# Python follows standard operator precedence (parentheses, exponents, multiplication/division, addition/subtraction).

# %%
print(100 / 100 * 100)
print(100 / (100 * 100))
result = (2 + 3) * (5 - 2) / 4 + 6**2 - 1
print(result)

# %% [markdown]
# ## 2. Worked example: NumPy

# %%
x = np.linspace(0, 30, 31)  # 31 values from 0 to 30 inclusive
y = np.linspace(0, 1, 100)
print(x[:5], '...', x[-3:])

z = np.sqrt(49)
z = np.deg2rad(z)
z = np.round(z, 3)
print('ln(z) =', np.log(z))
print('log10(1e5) =', np.log10(100000))
print('pi =', np.pi)
print(np.sin(np.pi / 2), np.cos(np.pi), np.arcsin(0.5))

# %%
z = np.arange(50)
print('sum', np.sum(z), 'max', np.max(z), 'min', np.min(z), 'mean', np.mean(z))

# %% [markdown]
# ## 3. Wrap-up
#
# - Open `lab01-activity.ipynb` next and complete the RO plant calculations.
# - A longer command reference is in `python_tutorial_commands.py` in this folder.
