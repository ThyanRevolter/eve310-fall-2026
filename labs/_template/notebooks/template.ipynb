# %% [markdown]
# # EVE 310 - Lab {{LAB_NUMBER}}: {{LAB_TITLE}}
#
# **Module {{MODULE}} | {{DATE}}**
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. TODO
# 2. TODO
# 3. TODO
#
# ## Before you start
#
# - Run `uv sync` in the repository root, then launch this notebook with `uv run jupyter lab` (see `docs/setup.md`).
# - Work through the cells in order. Cells marked **Your turn** are for you to complete.

# %% [markdown]
# ## 0. Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from eve310 import set_plot_style

set_plot_style()

# %% [markdown]
# ## 1. Load the data

# %%
# df = pd.read_csv("../data/{{LAB_ID}}_example.csv")
# df.head()

# %% [markdown]
# ## 2. Worked example

# %% [markdown]
# ## 3. Your turn
#
# **Exercise 1.** TODO

# %%
# Your code here

# %% [markdown]
# ## 4. Wrap-up
#
# - Save any figures to `../figures/`.
# - Submit through Canvas/Gradescope as described in `../README.md`.
