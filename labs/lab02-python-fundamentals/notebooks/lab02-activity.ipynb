# %% [markdown]
# # EVE 310 - Lab 02: Python fundamentals — activity
#
# **Module 1 | 09/03/2026**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThyanRevolter/eve310-fall-2026/blob/main/labs/lab02-python-fundamentals/notebooks/lab02-activity.ipynb)
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. Practice strings, imports, and 1D/2D indexing
# 2. Load Jester Hall water data and extract the consumption column
#
# ## Before you start
#
# - **On your laptop:** run `uv sync` in the repository root, then launch this notebook with `uv run jupyter lab` (see `docs/setup.md`).
# - **In Google Colab:** click *Copy to Drive* first, or your work is lost when the tab closes.
# - Either way, run the setup cell below before anything else. It sets `DATA_DIR` to wherever this lab's data files live.
# - Work through the cells in order. Cells marked **Your turn** are for you to complete.

# %% [markdown]
# Complete each section. Replace `--` with your code.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd

# Course setup: run this cell first. It works on your laptop and in Google Colab.
LAB = "lab02-python-fundamentals"
try:
    from eve310 import setup_notebook
except ModuleNotFoundError:
    # Colab starts from a blank machine, so download the course files first.
    # !test -d /content/eve310 || git clone -q --depth 1 https://github.com/ThyanRevolter/eve310-fall-2026.git /content/eve310
    import sys
    sys.path.insert(0, "/content/eve310/src")
    from eve310 import setup_notebook

DATA_DIR, FIGURES_DIR = setup_notebook(LAB)

# %% [markdown]
# ## Your turn
#
# **Part 1 — Hello World**
#
# 1. Create a string with the value `'Hello World!'`
# 2. Print the string

# %%
a = --
print(a)

# %% [markdown]
# **Part 2 — Importing packages**
#
# Import numpy as `np` and pandas as `pd`. (You may already have done this above.)

# %%
import -- as --
import -- as --

# %% [markdown]
# **Part 3 — 1D lists and arrays**
#
# 1. `my_list` with values 4, 8, 1, 0, 3, 5, 2
# 2. Print the fourth value and the first value
# 3. `my_array` with the same values
# 4. Sum of the third, sixth, and seventh values
# 5. Sum of the first six values
# 6. Sum of all values
# 7. Seventh element raised to the power of the first element

# %%
my_list = --
print('The fourth value of my_list is', my_list[-])
print('The first value of my_list is', my_list[-])

my_array = np.array(--)
my_sum_1 = my_array[--] + my_array[--] + my_array[--]
print('The sum of the third, sixth, and seventh value of my_array is', my_sum_1)

my_sum_2 = np.sum(my_array[--])
print('The sum of the first six values of my_array is', my_sum_2)

total_sum = --
print('The overall sum of my_array is', total_sum)

my_exp = my_array[--] ** my_array[--]
print('The value of the computed exponent is', my_exp)

# %% [markdown]
# **Part 4 — 2D arrays**
#
# Create a 3×2 array: row 1: 4, 9; row 2: 5, 3; row 3: 6, 8. Print the array, the value in the second row / first column, and all rows of the second column.

# %%
array_2d = --
print(array_2d)
print(array_2d[--])
print(array_2d[--])

# %% [markdown]
# **Part 5 — Importing data**
#
# Load `DATA_DIR / 'JES_Water.csv'` (Jester Hall water, 2009–2017). Extract all rows of the fifth column as `water_con`. Print the 22nd value — it should be `15.89`.

# %%
water_df = --
water_array = water_df.to_numpy()
water_con = water_array[--]
print(water_con[--])

# %% [markdown]
# **Part 6 — Quiz scratch space**
#
# The Canvas quiz will ask questions about `water_con`. Use the cell below during the quiz.

# %%
# Use this cell for quiz calculations

# %% [markdown]
# ## Wrap-up
#
# Save the notebook. Submit as described in `../README.md`.
