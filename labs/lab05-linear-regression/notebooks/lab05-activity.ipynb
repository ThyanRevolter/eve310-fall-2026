# %% [markdown]
# # EVE 310 - Lab 05: Linear regression — activity
#
# **Module 2 | 09/24/2026**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThyanRevolter/eve310-fall-2026/blob/main/labs/lab05-linear-regression/notebooks/lab05-activity.ipynb)
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. Inspect coefficients, change the train/test split, and reason about `random_state`
#
# ## Before you start
#
# - Run `uv sync` in the repository root, then launch this notebook with `uv run jupyter lab` (see `docs/setup.md`).
# - Work through the cells in order. Cells marked **Your turn** are for you to complete.

# %% [markdown]
# Use the **tutorial notebook** (save a copy or work in cells below).

# %% [markdown]
# ## Your turn
#
# 1. Print the intercept and coefficients (`betas`) of the univariate and multivariate models.
#    - How many betas does each model have?
#    - What are the values?
#
# 2. Change both models to a **60% / 40%** train/test split. Keep `random_state=45`.
#    - New betas?
#    - New R² and adjusted R²?
#
# 3. Print `x_test` after the split. Change `random_state` and split again. Does `x_test` stay the same? What does that imply?
#
# 4. Remove `random_state=45` and re-run a few times. Do betas and R² change? Are the changes large?

# %%
# Scratch space — copy/modify cells from the tutorial

# %% [markdown]
# ## Wrap-up
#
# Submit as described in `../README.md`.
