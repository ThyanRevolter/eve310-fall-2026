# %% [markdown]
# # EVE 310 - Lab 07: If statements and for loops — activity
#
# **Module 3 | 10/08/2026**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ThyanRevolter/eve310-fall-2026/blob/main/labs/lab07-control-flow/notebooks/lab07-activity.ipynb)
#
# ## Learning objectives
#
# By the end of this lab you will be able to:
#
# 1. Find a minimum and a sum with a for loop; check against NumPy
#
# ## Before you start
#
# 1. Click **Copy to Drive** at the top of this window and work in the copy that opens. Colab throws away anything you did not copy when the runtime ends.
# 2. Run the setup cell below before anything else. It creates `DATA_DIR` and `FIGURES_DIR` for this lab.
# 3. Work down the notebook in order. Cells marked **Your turn** are the ones you complete.
# 4. When you are done: **Runtime > Restart session and run all**, then **File > Download > Download .ipynb**, and upload that file to Gradescope.

# %% [markdown]
# `rand_dist` is 100,000 draws from a normal distribution with mean 0 and standard deviation 20.
#
# A. Use a for loop and if statement to find the **minimum**. Check with `np.min`.
#
# B. Sum all values with a for loop. Check with `np.sum`.

# %% [markdown]
# ## 0. Setup

# %%
# EVE 310 setup - run this cell first, every time you open this notebook.
import pathlib

LAB = "lab07-control-flow"

DATA_DIR = pathlib.Path("data")
FIGURES_DIR = pathlib.Path("figures")
DATA_DIR.mkdir(exist_ok=True)
FIGURES_DIR.mkdir(exist_ok=True)

print(f"Ready. This lab needs no data files; save any figures to {FIGURES_DIR.resolve()}")

# %%
import numpy as np
np.random.seed(0)

# %% [markdown]
# ## Your turn

# %%
vals = 100_000
rand_dist = np.random.normal(0, 20, vals)

# A. minimum via loop + if

# Check: print(min_val == np.min(rand_dist))

# %%
# B. sum via loop

# Check: print(np.isclose(loop_sum, np.sum(rand_dist)))

# %% [markdown]
# ## Wrap-up
#
# Submit as described in `../README.md`.
